# %%
## import 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import seaborn as sns 
from scipy.stats import skew
import math

# %%
## Lets import the train and test data 
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
# only the SalePrice column is missing in test data which is the target 
# drop the id columns in both of them 

df_train.drop('Id',axis=1,inplace=True)
df_test.drop('Id',axis=1,inplace=True)

# see the shape of both of them 
df_train.shape,df_test.shape
# Out:
# ((1460, 80), (1459, 79))

# %%
# make function to not repeat your work when you deal with tes data
def check_missing_values(df):
        number = df.isnull().sum().sort_values(ascending=False)
        percentage = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
        sns.barplot(number.index[:5],number[:5])
        df_missing = pd.concat([number,percentage],axis=1,keys=['number','percentage'])
        return df_missing

# %%
check_missing_values(df_train).head(10)
# Out:
#               number  percentage
# PoolQC          1453    0.995205
# MiscFeature     1406    0.963014
# Alley           1369    0.937671
# Fence           1179    0.807534
# FireplaceQu      690    0.472603
# LotFrontage      259    0.177397
# GarageType        81    0.055479
# GarageCond        81    0.055479
# GarageFinish      81    0.055479
# GarageQual        81    0.055479

# %%
# for test data 
check_missing_values(df_test).head(10)
# Out:
#               number  percentage
# PoolQC          1456    0.997944
# MiscFeature     1408    0.965045
# Alley           1352    0.926662
# Fence           1169    0.801234
# FireplaceQu      730    0.500343
# LotFrontage      227    0.155586
# GarageCond        78    0.053461
# GarageFinish      78    0.053461
# GarageYrBlt       78    0.053461
# GarageQual        78    0.053461

# %%
# drop the top 5 since it has the its common and have mor than 50% missing values 
removed_columns = check_missing_values(df_train).index
def remove_columns(df):
    for element in removed_columns[:5]:
        df.drop(element,axis=1,inplace=True)

# %%
for element in removed_columns[:5]:
    print(element)
# Out:
# PoolQC
# MiscFeature
# Alley
# Fence
# FireplaceQu

# %%
remove_columns(df_test)

# %%
remove_columns(df_train)

# %%
check_missing_values(df_test)
# Out:
#               number  percentage
# LotFrontage      227    0.155586
# GarageFinish      78    0.053461
# GarageCond        78    0.053461
# GarageQual        78    0.053461
# GarageYrBlt       78    0.053461
# ...              ...         ...
# 1stFlrSF           0    0.000000
# Electrical         0    0.000000
# CentralAir         0    0.000000
# HeatingQC          0    0.000000
# MSSubClass         0    0.000000
#
# [74 rows x 2 columns]

# %%
## After We remove the most missing colimns now we need to seperater our numirical and catoregical values 
def show_num(df):
    df_num = pd.DataFrame(data=None)
    for label,content in df.items():
        if(pd.api.types.is_numeric_dtype(content)):
            df_num[label] = content
    return df_num

# %%
df_train_num = show_num(df_train)
df_test_num = show_num(df_test)

# %%
# now do the same for the catogrical values 
def show_string(df):
    df_string= pd.DataFrame(data=None)
    for label,content in df.items():
        if(pd.api.types.is_string_dtype(content)):
            df_string[label] = content
    return df_string

# %%
df_train_string=show_string(df_train)
df_test_string = show_string(df_test)

# %%
df_train_num.shape,df_test_num.shape,df_train_string.shape,df_test_string.shape
# Out:
# ((1460, 37), (1459, 36), (1460, 43), (1459, 38))

# %%
# now see which has more coorlation 
def show_corr(df):
    top = df.corr().index[abs(df.corr()['SalePrice'])>0.6]
    fig,ax = plt.subplots(figsize=(10,10))
    ax = sns.heatmap(df[top].corr(),annot=True,fmt='.2f',linewidths=0.5,cmap='YlGnBu')
    return top

# %%
best_fetures_num=show_corr(df_train_num)

# %%
# make plot 
sns.set()
sns.pairplot(df_train[best_fetures_num],height=4)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Check the outlayer
# * There is one outlayer in TotalBsmtSF above 6000
# * there is one out layer in 1stFlrSF above 4000
# * there are two outlayer in GrLivArea above 4000 and below 200000 in price
# *  there are four outlaier in GarageArea above 1200 and below 400000 in price

# %%
# reomving the outlayer 
df_train = df_train.drop(df_train[(df_train['GrLivArea']>4000) & (df_train['SalePrice']<300000)].index)
df_train = df_train.drop(df_train[(df_train['TotalBsmtSF']>6000)].index)
df_train = df_train.drop(df_train[(df_train['GarageArea']>1200) & (df_train['SalePrice']<400000)].index)
df_train = df_train.drop(df_train[(df_train['1stFlrSF']>4000)].index)

# %%
# check after removing outlayres 
sns.set()
sns.pairplot(df_train[best_fetures_num],height=4)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# split the num values again 
df_train_num = show_num(df_train)
check_missing_values(df_train_num)
# Out:
#                number  percentage
# LotFrontage       258    0.177442
# GarageYrBlt        81    0.055708
# MasVnrArea          8    0.005502
# SalePrice           0    0.000000
# BsmtUnfSF           0    0.000000
# GrLivArea           0    0.000000
# LowQualFinSF        0    0.000000
# 2ndFlrSF            0    0.000000
# 1stFlrSF            0    0.000000
# TotalBsmtSF         0    0.000000
# BsmtFinSF1          0    0.000000
# BsmtFinSF2          0    0.000000
# BsmtHalfBath        0    0.000000
# YearRemodAdd        0    0.000000
# YearBuilt           0    0.000000
# OverallCond         0    0.000000
# OverallQual         0    0.000000
# LotArea             0    0.000000
# BsmtFullBath        0    0.000000
# FullBath            0    0.000000
# YrSold              0    0.000000
# OpenPorchSF         0    0.000000
# MoSold              0    0.000000
# MiscVal             0    0.000000
# PoolArea            0    0.000000
# ScreenPorch         0    0.000000
# ...

# %%
# since the mean is almost near to the median fill the missing values with mean
def fill_LotFrontage(df):
    df['LotFrontage'].describe()
    df['LotFrontage'].fillna('mean',inplace=True)
    print(f'the number of null is {df["LotFrontage"].isnull().sum()}')

# %%
fill_LotFrontage(df_test)
fill_LotFrontage(df_train)
# Out:
# the number of null is 0
# the number of null is 0

# %%
# fill GarageYrBlt with the next values 
df_train['GarageYrBlt'].fillna(method='ffill',inplace=True)
df_test['GarageYrBlt'].fillna(method='ffill',inplace=True)

# %%
# fill with zeros since it has alot of zeros
df_train['MasVnrArea'].fillna(value=0,inplace=True)
df_test['MasVnrArea'].fillna(value=0,inplace=True)

# %%
# split again 
df_train_num=show_num(df_train)
df_test_num=show_num(df_test)

# %%
check_missing_values(df_train_num)
# Out:
#                number  percentage
# SalePrice           0         0.0
# YrSold              0         0.0
# BsmtFullBath        0         0.0
# GrLivArea           0         0.0
# LowQualFinSF        0         0.0
# 2ndFlrSF            0         0.0
# 1stFlrSF            0         0.0
# TotalBsmtSF         0         0.0
# BsmtUnfSF           0         0.0
# BsmtFinSF2          0         0.0
# BsmtFinSF1          0         0.0
# MasVnrArea          0         0.0
# YearRemodAdd        0         0.0
# YearBuilt           0         0.0
# OverallCond         0         0.0
# OverallQual         0         0.0
# LotArea             0         0.0
# BsmtHalfBath        0         0.0
# FullBath            0         0.0
# HalfBath            0         0.0
# OpenPorchSF         0         0.0
# MoSold              0         0.0
# MiscVal             0         0.0
# PoolArea            0         0.0
# ScreenPorch         0         0.0
# 3SsnPorch           0         0.0
# ...

# %%
check_missing_values(df_test_num)
# Out:
#                number  percentage
# BsmtHalfBath        2    0.001371
# BsmtFullBath        2    0.001371
# BsmtFinSF1          1    0.000685
# TotalBsmtSF         1    0.000685
# BsmtUnfSF           1    0.000685
# BsmtFinSF2          1    0.000685
# GarageCars          1    0.000685
# GarageArea          1    0.000685
# MasVnrArea          0    0.000000
# YearRemodAdd        0    0.000000
# YearBuilt           0    0.000000
# OverallCond         0    0.000000
# OverallQual         0    0.000000
# LotArea             0    0.000000
# 1stFlrSF            0    0.000000
# 2ndFlrSF            0    0.000000
# LowQualFinSF        0    0.000000
# GrLivArea           0    0.000000
# YrSold              0    0.000000
# FullBath            0    0.000000
# MoSold              0    0.000000
# HalfBath            0    0.000000
# BedroomAbvGr        0    0.000000
# KitchenAbvGr        0    0.000000
# TotRmsAbvGrd        0    0.000000
# Fireplaces          0    0.000000
# ...

# %%
# fill the reaminng mising with 0 
for labels,content in df_test.items():
    if(pd.api.types.is_numeric_dtype(content)):
        if(df_test[labels].isnull().sum()):
            df_test[labels].fillna(value=0,inplace=True)

# %%
df_test_num = show_num(df_test)
check_missing_values(df_test_num)
# Out:
#                number  percentage
# YrSold              0         0.0
# BsmtFinSF2          0         0.0
# GrLivArea           0         0.0
# LowQualFinSF        0         0.0
# 2ndFlrSF            0         0.0
# 1stFlrSF            0         0.0
# TotalBsmtSF         0         0.0
# BsmtUnfSF           0         0.0
# BsmtFinSF1          0         0.0
# BsmtHalfBath        0         0.0
# MasVnrArea          0         0.0
# YearRemodAdd        0         0.0
# YearBuilt           0         0.0
# OverallCond         0         0.0
# OverallQual         0         0.0
# LotArea             0         0.0
# BsmtFullBath        0         0.0
# FullBath            0         0.0
# MoSold              0         0.0
# WoodDeckSF          0         0.0
# MiscVal             0         0.0
# PoolArea            0         0.0
# ScreenPorch         0         0.0
# 3SsnPorch           0         0.0
# EnclosedPorch       0         0.0
# OpenPorchSF         0         0.0
# ...

# %% [markdown]
# # Catogrical Values

# %%
df_train_string = show_string(df_train)
df_test_string = show_string(df_test)
df_train_string.T
# Out:
#                   0        1        2        3        4        5        6     \
# MSZoning            RL       RL       RL       RL       RL       RL       RL
# LotFrontage         65       80       68       60       84       85       75
# Street            Pave     Pave     Pave     Pave     Pave     Pave     Pave
# LotShape           Reg      Reg      IR1      IR1      IR1      IR1      Reg
# LandContour        Lvl      Lvl      Lvl      Lvl      Lvl      Lvl      Lvl
# Utilities       AllPub   AllPub   AllPub   AllPub   AllPub   AllPub   AllPub
# LotConfig       Inside      FR2   Inside   Corner      FR2   Inside   Inside
# LandSlope          Gtl      Gtl      Gtl      Gtl      Gtl      Gtl      Gtl
# Neighborhood   CollgCr  Veenker  CollgCr  Crawfor  NoRidge  Mitchel  Somerst
# Condition1        Norm    Feedr     Norm     Norm     Norm     Norm     Norm
# Condition2        Norm     Norm     Norm     Norm     Norm     Norm     Norm
# ...

# %%
df_train['HeatingQC'].value_counts()
# Out:
# Ex    736
# TA    427
# Gd    241
# Fa     49
# Po      1
# Name: HeatingQC, dtype: int64

# %%
df_train['LotFrontage'].value_counts()
# Out:
# mean     258
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
#         ...
# 114.0      1
# 112.0      1
# 111.0      1
# 106.0      1
# 138.0      1
# Name: LotFrontage, Length: 111, dtype: int64

# %%
df_train['ExterQual'].value_counts()
# Out:
# TA    905
# Gd    488
# Ex     48
# Fa     13
# Name: ExterQual, dtype: int64

# %%
df_train['GarageCond'].value_counts()
# Out:
# TA    1320
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: GarageCond, dtype: int64

# %%
'TA' in df_train_string['GarageCond'].value_counts()
# Out:
# True

# %% [markdown]
# ## In catogrical values we we will seprate the data into three main secton
# * section 1 the catogrical value that has few content like asseemtn or grade or quality grade
# * section 2 we will seprate the numrical values that is in catrogical form
# * section 3 we wil deal with dummy variables

# %% [markdown]
# ### section 1

# %%
def sep1(df):
    lisit=[]
   
    for label,content in df.items():
        if('TA' in df[label].value_counts()):
            lisit.append(label)
            df[label]=content.astype('category').cat.as_ordered() # conver it to categorica
            df[label]=pd.Categorical(content).codes+1  # convert it to numrical and fill mising values

# %%
sep1(df_train)
sep1(df_test)

# %%
check_missing_values(df_train)
# Out:
#                number  percentage
# GarageType         81    0.055708
# GarageFinish       81    0.055708
# GarageCond         81    0.055708
# GarageQual         81    0.055708
# BsmtFinType2       38    0.026135
# ...               ...         ...
# 1stFlrSF            0    0.000000
# CentralAir          0    0.000000
# HeatingQC           0    0.000000
# SaleCondition       0    0.000000
# MSSubClass          0    0.000000
#
# [75 rows x 2 columns]

# %%
check_missing_values(df_train)
# Out:
#               number  percentage
# GarageType        81    0.055708
# GarageFinish      81    0.055708
# BsmtFinType2      38    0.026135
# BsmtExposure      38    0.026135
# BsmtFinType1      37    0.025447
# ...              ...         ...
# BedroomAbvGr       0    0.000000
# KitchenAbvGr       0    0.000000
# KitchenQual        0    0.000000
# TotRmsAbvGrd       0    0.000000
# MSSubClass         0    0.000000
#
# [75 rows x 2 columns]

# %% [markdown]
# ## Section Two

# %%
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: GarageYrBlt, Length: 1454, dtype: bool

# %%
df_train['LotFrontage']=df_train['LotFrontage'].replace('mean',2002)
df_test['LotFrontage']=df_test['LotFrontage'].replace('mean',2002)

# %% [markdown]
# ## Section three

# %%
# split again 
df_train_string=show_string(df_train)

# %%
df_train_string.T
# Out:
#                   0        1        2        3        4        5        6     \
# MSZoning            RL       RL       RL       RL       RL       RL       RL
# Street            Pave     Pave     Pave     Pave     Pave     Pave     Pave
# LotShape           Reg      Reg      IR1      IR1      IR1      IR1      Reg
# LandContour        Lvl      Lvl      Lvl      Lvl      Lvl      Lvl      Lvl
# Utilities       AllPub   AllPub   AllPub   AllPub   AllPub   AllPub   AllPub
# LotConfig       Inside      FR2   Inside   Corner      FR2   Inside   Inside
# LandSlope          Gtl      Gtl      Gtl      Gtl      Gtl      Gtl      Gtl
# Neighborhood   CollgCr  Veenker  CollgCr  Crawfor  NoRidge  Mitchel  Somerst
# Condition1        Norm    Feedr     Norm     Norm     Norm     Norm     Norm
# Condition2        Norm     Norm     Norm     Norm     Norm     Norm     Norm
# BldgType          1Fam     1Fam     1Fam     1Fam     1Fam     1Fam     1Fam
# ...

# %%
dftrain = pd.get_dummies(df_train)

# %%
dftest = pd.get_dummies(df_test)

# %%
check_missing_values(df_train)
# Out:
#               number  percentage
# GarageType        81    0.055708
# GarageFinish      81    0.055708
# BsmtFinType2      38    0.026135
# BsmtExposure      38    0.026135
# BsmtFinType1      37    0.025447
# ...              ...         ...
# BedroomAbvGr       0    0.000000
# KitchenAbvGr       0    0.000000
# KitchenQual        0    0.000000
# TotRmsAbvGrd       0    0.000000
# MSSubClass         0    0.000000
#
# [75 rows x 2 columns]

# %%
df_train.fillna(value='none',inplace=True)
df_test.fillna(value='none',inplace=True)

# %%
dftrain
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
dftrain = pd.get_dummies(df_train)
dftest = pd.get_dummies(df_test)

# %%
# Out:
#               number  percentage
# SalePrice          0         0.0
# YearRemodAdd       0         0.0
# RoofMatl           0         0.0
# Exterior1st        0         0.0
# Exterior2nd        0         0.0
# ...              ...         ...
# KitchenAbvGr       0         0.0
# KitchenQual        0         0.0
# TotRmsAbvGrd       0         0.0
# Functional         0         0.0
# MSSubClass         0         0.0
#
# [75 rows x 2 columns]

# %%
from sklearn.linear_model import Lasso
import sklearn.model_selection as ms

# %% [markdown]
# ## Modeling

# %%
x = dftrain.drop('SalePrice',axis=1)
y= dftrain['SalePrice']
np.random.seed(42)
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,)

# %%
def show_scores(model):
    ytprediction = model.predict(x_train)
    yteprediction = model.predict(x_test)
    scores = {
          'Training root mean sequare error':np.sqrt(mean_squared_error(y_train,ytprediction)),
          'Validation root mean sequare error':np.sqrt(mean_squared_error(y_test,yteprediction)),
          'R2 training':r2_score(y_train,ytprediction),
          'R2 Validation':r2_score(y_test,yteprediction),
            'mae Training': mean_absolute_error(y_train,ytprediction),
             'mae valid': mean_absolute_error(y_test,yteprediction)}
    return scores

# %%
# fit the model 
modelRand = RandomForestRegressor()
modelRand.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
show_scores(modelRand)
# Out:
# {'Training root mean sequare error': 10075.678051491917,
#  'Validation root mean sequare error': 24130.850514308215,
#  'R2 training': 0.9839876747456648,
#  'R2 Validation': 0.9039561504312567,
#  'mae Training': 6416.575606190885,
#  'mae valid': 16533.498247422678}

# %%
lasso = Lasso(tol=0.001)
lasso.fit(x_train,y_train)
# Out:
# C:\Users\ittim\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 154036489310.95966, tolerance: 7373503241.917543
#   positive)
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.001, warm_start=False)

# %%
show_scores(lasso)
# Out:
# {'Training root mean sequare error': 20293.198025323964,
#  'Validation root mean sequare error': 23885.61591229393,
#  'R2 training': 0.9350458616732165,
#  'R2 Validation': 0.9058983606962695,
#  'mae Training': 14034.686159447889,
#  'mae valid': 16969.728531119992}

# %%
## not goood 
from scipy.stats import skew
from scipy import stats

# %%
# we should make normal dirubution 
sns.distplot(df_train['SalePrice']);
fig = plt.figure()
res = stats.probplot(df_train['SalePrice'], plot=plt);

# %%
df_train['SalePrice'] = np.log1p(df_train['SalePrice'])
sns.distplot(df_train['SalePrice']);
fig = plt.figure()
res = stats.probplot(df_train['SalePrice'], plot=plt)

# %%
dftrain = pd.get_dummies(df_train)
dftest = pd.get_dummies(df_test)

# %%
x = dftrain.drop('SalePrice',axis=1)
y= dftrain['SalePrice']
np.random.seed(42)
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,)

# %%
modelRand = RandomForestRegressor()
modelRand.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
show_scores(modelRand)
# Out:
# {'Training root mean sequare error': 0.051405142097486464,
#  'Validation root mean sequare error': 0.1400426201674781,
#  'R2 training': 0.9830136486055727,
#  'R2 Validation': 0.8856902665563748,
#  'mae Training': 0.03564543197544857,
#  'mae valid': 0.09212907341931287}

# %%
lasso = Lasso(tol=0.00001)
lasso.fit(x_train,y_train)
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=1e-05, warm_start=False)

# %%
show_scores(lasso)
# Out:
# {'Training root mean sequare error': 0.16507304610940887,
#  'Validation root mean sequare error': 0.17770779356471067,
#  'R2 training': 0.8248382373143863,
#  'R2 Validation': 0.8159330966942371,
#  'mae Training': 0.11679180308102899,
#  'mae valid': 0.12364553222567361}

# %%
from sklearn.model_selection import RandomizedSearchCV

## Create distrbution 
rf_grid = {'n_estimators':[100,200,300,500],
            'max_depth': [None,3,5,10],
           'min_samples_split':np.arange(2,20,2),
           'min_samples_leaf':np.arange(1,20,2),
            'max_features':[0.5,1,'sqrt','auto']
         }

# initiate Randomize Search mode; 
rs_model =RandomizedSearchCV(RandomForestRegressor(n_jobs= -1,
                                                  random_state=42),rf_grid,n_iter=20,
                              cv=5, verbose=True )

# fitting

rs_model.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:  2.4min finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
# ...

# %%
rs_model.best_params_
# Out:
# {'n_estimators': 500,
#  'min_samples_split': 14,
#  'min_samples_leaf': 7,
#  'max_features': 0.5,
#  'max_depth': 10}

# %%
show_scores(rs_model)
# Out:
# {'Training root mean sequare error': 0.10290575647886573,
#  'Validation root mean sequare error': 0.14624892678701082,
#  'R2 training': 0.9319283441146652,
#  'R2 Validation': 0.8753339692472035,
#  'mae Training': 0.06875906788767835,
#  'mae valid': 0.09610023408798223}

# %%
show_scores(modelRand)
# Out:
# {'Training root mean sequare error': 0.051405142097486464,
#  'Validation root mean sequare error': 0.1400426201674781,
#  'R2 training': 0.9830136486055727,
#  'R2 Validation': 0.8856902665563748,
#  'mae Training': 0.03564543197544857,
#  'mae valid': 0.09212907341931287}

# %%
## this is the return df_test_string['Ss']=np.expm1(dftrain['SalePrice'])
df_test_string.drop('Ss',axis=1,inplace=True)

# %%
x_test_real = dftest

# %%
dftrain.columns
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
dftest.columns
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        ...
#        'SaleType_New', 'SaleType_Oth', 'SaleType_WD', 'SaleType_none',
#        'SaleCondition_Abnorml', 'SaleCondition_AdjLand',
#        'SaleCondition_Alloca', 'SaleCondition_Family', 'SaleCondition_Normal',
#        'SaleCondition_Partial'],
#       dtype='object', length=239)

# %%
li =[]
for element in dftrain:
    if(element not in dftest):
        li.append(element)

# %%
li.remove('SalePrice')

# %%
df_train2 = dftrain.drop(liss,axis=1)

# %%
x = df_train2.drop('SalePrice',axis=1)
y= df_train2['SalePrice']
np.random.seed(42)
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,)

# %%
modelRand = RandomForestRegressor()
modelRand.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
show_scores(modelRand)
# Out:
# {'Training root mean sequare error': 0.05169210521955184,
#  'Validation root mean sequare error': 0.14105607704593842,
#  'R2 training': 0.9828234706674419,
#  'R2 Validation': 0.8840298124978161,
#  'mae Training': 0.035803558717585914,
#  'mae valid': 0.09334647242756096}

# %%
liss =[]
for element in dftrain.columns:
    if(element not in dftest.columns):
        liss.append(element)

# %%
dftrain
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
np.array(dftest.columns) == np.array(dftrain.columns)
# Out:
# C:\Users\ittim\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   """Entry point for launching an IPython kernel.
# False

# %%
df_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1455          60       RL         62.0     7917   Pave      Reg         Lvl
# 1456          20       RL         85.0    13175   Pave      Reg         Lvl
# 1457          70       RL         66.0     9042   Pave      Reg         Lvl
# 1458          20       RL         68.0     9717   Pave      Reg         Lvl
# 1459          20       RL         75.0     9937   Pave      Reg         Lvl
#
# ...

# %%
df_test
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             20       RH         80.0    11622   Pave      Reg         Lvl
# 1             20       RL         81.0    14267   Pave      IR1         Lvl
# 2             60       RL         74.0    13830   Pave      IR1         Lvl
# 3             60       RL         78.0     9978   Pave      IR1         Lvl
# 4            120       RL         43.0     5005   Pave      IR1         HLS
# ...          ...      ...          ...      ...    ...      ...         ...
# 1454         160       RM         21.0     1936   Pave      Reg         Lvl
# 1455         160       RM         21.0     1894   Pave      Reg         Lvl
# 1456          20       RL        160.0    20000   Pave      Reg         Lvl
# 1457          85       RL         62.0    10441   Pave      Reg         Lvl
# 1458          60       RL         74.0     9627   Pave      Reg         Lvl
#
# ...

# %%
df = pd.concat((df_train,df_test)).reset_index(drop=True)

# %%
df_dummy = pd.get_dummies(df)

# %%
df_realtest = df_dummy[df_dummy['SalePrice'].isnull()].drop('SalePrice',axis=1,inplace=True)
df_real_train = df_dummy[df_dummy['SalePrice']>0]

# %%
x = df_real_train.drop('SalePrice',axis=1)
y= df_real_train['SalePrice']
np.random.seed(42)
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,)

# %%
modelRand = RandomForestRegressor()
modelRand.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
show_scores(modelRand)
# Out:
# {'Training root mean sequare error': 0.05164657566348466,
#  'Validation root mean sequare error': 0.13983927165918447,
#  'R2 training': 0.9828537149512871,
#  'R2 Validation': 0.886021991820291,
#  'mae Training': 0.03585583890490708,
#  'mae valid': 0.09279015870214004}

# %%
xp=df_dummy[df_dummy['SalePrice'].isnull()].drop('SalePrice',axis=1)

# %%
yp = modelRand.predict(xp)

# %%
yp
# Out:
# array([11.72521259, 11.92507246, 12.07876805, ..., 11.96608174,
#        11.65509487, 12.35674748])

# %%
## this is the return df_test_string['Ss']=np.expm1(dftrain['SalePrice'])
yr = np.expm1(yp)

# %% [raw]
# yr

# %%
yr.size
# Out:
# 1459

# %%
dfTest = pd.read_csv('test.csv')
dfTest
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
df_test
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             20       RH         80.0    11622   Pave      Reg         Lvl
# 1             20       RL         81.0    14267   Pave      IR1         Lvl
# 2             60       RL         74.0    13830   Pave      IR1         Lvl
# 3             60       RL         78.0     9978   Pave      IR1         Lvl
# 4            120       RL         43.0     5005   Pave      IR1         HLS
# ...          ...      ...          ...      ...    ...      ...         ...
# 1454         160       RM         21.0     1936   Pave      Reg         Lvl
# 1455         160       RM         21.0     1894   Pave      Reg         Lvl
# 1456          20       RL        160.0    20000   Pave      Reg         Lvl
# 1457          85       RL         62.0    10441   Pave      Reg         Lvl
# 1458          60       RL         74.0     9627   Pave      Reg         Lvl
#
# ...

# %%
eme = pd.DataFrame(None)

# %%
np.arange(1461,2920).size
# Out:
# 1459

# %%
eme['Id']= np.arange(1461,2920)
eme['SalePrice']=yr

# %% [markdown]
# eme

# %%
eme
# Out:
#         id      SalePrice
# 0     1461  123649.287005
# 1     1462  151004.638601
# 2     1463  176092.088410
# 3     1464  182430.658891
# 4     1465  196871.857613
# ...    ...            ...
# 1454  2915   86025.725866
# 1455  2916   84464.516095
# 1456  2917  157326.002411
# 1457  2918  115276.191846
# 1458  2919  232522.710065
#
# [1459 rows x 2 columns]

# %%
eme.to_csv('House Price Prediction.csv')
